# %% [markdown]
# # Returns Analysis

# %%
# Install required packages
# !pip install pandas numpy ipython
# Out:
# Requirement already satisfied: pandas in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (2.3.4)
# Requirement already satisfied: ipython in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (9.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: decorator in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from stack_data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from stack_data->ipython) (0.2.3)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Compute log-return diagnostics to understand drift, volatility, and autocorrelation before training transformers.
# Tweak the configuration and re-run to focus on different subsets or export results.

# %%
from dataclasses import dataclass
from pathlib import Path
from typing import Iterable, List

import numpy as np
import pandas as pd
from IPython.display import display

# %%
TRADING_DAYS_PER_YEAR = 252

@dataclass
class ReturnSummary:
    symbol: str
    category: str
    observations: int
    mean_log_return: float
    median_log_return: float
    std_log_return: float

    annual_drift: float
    annual_vol: float
    skew: float
    kurt: float
    pct_positive: float
    lag1_autocorr: float


def compute_log_returns(path: Path) -> ReturnSummary | None:
    try:
        df = pd.read_csv(path, parse_dates=['Date'])
    except Exception as exc:
        print(f'[WARN] Could not load {path}: {exc}')
        return None

    if df.empty or len(df) < 5:
        return None

    df = df.sort_values('Date')
    close = df['Close'].astype(float)
    log_returns = np.log(close).diff().dropna()
    if log_returns.empty:
        return None

    mean_lr = float(log_returns.mean())
    std_lr = float(log_returns.std(ddof=0))
    annual_vol = float(std_lr * np.sqrt(TRADING_DAYS_PER_YEAR))
    annual_drift = float(mean_lr * TRADING_DAYS_PER_YEAR)
    lag1 = float(log_returns.autocorr(lag=1) or 0.0)

    return ReturnSummary(
        symbol=path.stem,
        category=path.parent.name,
        observations=len(log_returns),
        mean_log_return=mean_lr,
        median_log_return=float(log_returns.median()),
        std_log_return=std_lr,
        annual_drift=annual_drift,
        annual_vol=annual_vol,
        skew=float(log_returns.skew()),
        kurt=float(log_returns.kurt()),
        pct_positive=float((log_returns > 0).mean()),
        lag1_autocorr=lag1,
    )


def gather_summaries(files: Iterable[Path]) -> List[ReturnSummary]:
    results: List[ReturnSummary] = []
    for path in files:
        summary = compute_log_returns(path)
        if summary is not None:
            results.append(summary)
    return results


def build_dataframe(summaries: Iterable[ReturnSummary]) -> pd.DataFrame:
    df = pd.DataFrame([s.__dict__ for s in summaries])
    if df.empty:
        raise RuntimeError('No return summaries generated. Check the data path.')
    df['signal_to_noise'] = df['mean_log_return'].abs() / df['std_log_return'].clip(lower=1e-12)
    df['sharpe_like'] = (
        df['mean_log_return'] * TRADING_DAYS_PER_YEAR
    ) / (df['std_log_return'] * np.sqrt(TRADING_DAYS_PER_YEAR)).replace(0, np.nan)
    return df


def print_global_highlights(df: pd.DataFrame) -> None:
    print('=== Return Distribution Highlights ===')
    print(f'Symbols analysed: {len(df)}')
    print(
        f'Median annual drift: {df['annual_drift'].median(): .4f} ' 
        f'(IQR: {df['annual_drift'].quantile(0.75): .4f} - {df['annual_drift'].quantile(0.25): .4f})'
    )
    print(
        f'Median annual volatility: {df['annual_vol'].median(): .2f} ' 
        f'(10th-90th pct: {df['annual_vol'].quantile(0.9): .2f} - {df['annual_vol'].quantile(0.1): .2f})'
    )
    median_autocorr = df['lag1_autocorr'].median()
    print(f'Median lag-1 autocorr: {median_autocorr: .4f}')

    by_category = (
        df.groupby('category')[['annual_vol', 'annual_drift', 'lag1_autocorr', 'signal_to_noise']]
        .median()
        .sort_index()
    )
    display(by_category)


def display_outliers(df: pd.DataFrame, metric: str, limit: int) -> None:
    if metric not in df:
        raise ValueError(f'Metric {metric} not found in dataframe')
    subset = df.nlargest(limit, metric)
    display(subset[['symbol', 'category', metric, 'annual_vol', 'annual_drift']])

# %% [markdown]
# ## Configuration

# %%
DATA_ROOT = Path('../stock_data')
LIMIT = 5
METRIC = 'signal_to_noise'  # choose from: annual_vol, annual_drift, signal_to_noise, sharpe_like, lag1_autocorr
OUTPUT_CSV = None  # e.g. Path('outputs/returns_analysis.csv')

# %% [markdown]
# ## Run Analysis

# %%
files = sorted(DATA_ROOT.glob('*/*.txt'))
if not files:
    raise RuntimeError(f'No symbol files found under {DATA_ROOT}')

summaries = gather_summaries(files)
df = build_dataframe(summaries)

print_global_highlights(df)
display_outliers(df, METRIC, LIMIT)

if OUTPUT_CSV:
    OUTPUT_CSV.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(OUTPUT_CSV, index=False)
    print(f'[INFO] Return stats saved to {OUTPUT_CSV}')
# Out:
# [WARN] Could not load ../stock_data/Stocks/accp.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/amrh.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/amrhw.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/asns.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/bbrx.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/bolt.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/boxl.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/bxg.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/ehr.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/fmax.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/gnst.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/hayu.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/jt.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/mapi.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/molc.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/otg.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/pbio.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/pxus.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/rbio.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/sail.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/sbt.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/scci.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/scph.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/send.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/sfix.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/srva.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/stnl.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/vist.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/vmet.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/wnfm.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/wspt.us.txt: No columns to parse from file
# [WARN] Could not load ../stock_data/Stocks/znwaa.us.txt: No columns to parse from file
# === Return Distribution Highlights ===
# Symbols analysed: 8455
# Median annual drift:  0.0434 (IQR:  0.1083 - -0.0230)
# Median annual volatility:  0.35 (10th-90th pct:  0.81 -  0.10)
# Median lag-1 autocorr: -0.0354
#           annual_vol  annual_drift  lag1_autocorr  signal_to_noise
# category
# ETFs        0.208222      0.042106      -0.039641         0.024133
# Stocks      0.384491      0.043734      -0.034313         0.018042
#         symbol category  signal_to_noise  annual_vol  annual_drift
# 3948   fxjp.us   Stocks         2.067565    0.108889      3.573907
# 7318   spro.us   Stocks         1.754141    0.308500      8.590543
# 4641    igz.us   Stocks         1.213097    0.032295     -0.621920
# 4058  ggzrw.us   Stocks         1.157038    1.106715    -20.327484
# 1617   alna.us   Stocks         1.051095    0.474434      7.916226

# %% [markdown]
# # Dataset Overview

# %%
# Install required packages
# !pip install pandas numpy ipython
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting numpy
#   Downloading numpy-2.3.4-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: ipython in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (9.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: decorator in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from jedi>=0.16->ipython) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from stack_data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/chinmayrawat/Desktop/CS222 git/.venv/lib/python3.13/site-packages (from stack_data->ipython) (0.2.3)
# Downloading pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 66.9 MB/s eta 0:00:00
# Downloading numpy-2.3.4-cp313-cp313-macosx_14_0_arm64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 60.2 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# Successfully installed numpy-2.3.4 pandas-2.3.3 pytz-2025.2 tzdata-2025.2
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Use this notebook to profile the available stock and ETF histories before building transformer models.
# Configure the paths and run each cell top-to-bottom to regenerate the summary tables.

# %%
from dataclasses import dataclass
from pathlib import Path
from typing import Iterable, List

import pandas as pd
from IPython.display import display

# %%
@dataclass
class SymbolSummary:
    symbol: str
    category: str
    rows: int
    start_date: pd.Timestamp
    end_date: pd.Timestamp
    median_close: float
    avg_close: float
    std_close: float
    avg_volume: float
    last_close: float


def summarize_symbol(path: Path) -> SymbolSummary | None:
    try:
        df = pd.read_csv(path, parse_dates=['Date'])
    except Exception as exc:
        print(f'[WARN] Failed to load {path}: {exc}')
        return None

    if df.empty:
        print(f'[WARN] {path} is empty - skipping')
        return None

    df = df.sort_values('Date')
    return SymbolSummary(
        symbol=path.stem,
        category=path.parent.name,
        rows=len(df),
        start_date=df['Date'].iloc[0],
        end_date=df['Date'].iloc[-1],
        median_close=float(df['Close'].median()),
        avg_close=float(df['Close'].mean()),
        std_close=float(df['Close'].std(ddof=0)),
        avg_volume=float(df['Volume'].mean()),
        last_close=float(df['Close'].iloc[-1]),
    )


def gather_summaries(files: Iterable[Path]) -> List[SymbolSummary]:
    summaries: List[SymbolSummary] = []
    for path in files:
        summary = summarize_symbol(path)
        if summary is not None:
            summaries.append(summary)
    return summaries


def build_dataframe(summaries: Iterable[SymbolSummary]) -> pd.DataFrame:
    df = pd.DataFrame([s.__dict__ for s in summaries])
    if df.empty:
        raise RuntimeError('No valid symbol data was found.')
    df['span_years'] = (df['end_date'] - df['start_date']).dt.days / 365.25
    return df


def print_headline_numbers(df: pd.DataFrame) -> None:
    total_symbols = len(df)
    categories = df['category'].value_counts()
    overall_start = df['start_date'].min().date()
    overall_end = df['end_date'].max().date()
    median_rows = int(df['rows'].median())

    print('=== Dataset Overview ===')
    print(f'Total symbols: {total_symbols}')
    for category, count in categories.items():
        print(f'  - {category}: {count}')
    print(f'Overall coverage: {overall_start} → {overall_end} ({(overall_end - overall_start).days} days)')
    print(f'Median observations per symbol: {median_rows}')


def display_top_lists(df: pd.DataFrame, limit: int) -> None:
    longest = df.sort_values('span_years', ascending=False).head(limit)
    latest = df.sort_values('end_date', ascending=False).head(limit)
    vol = df.sort_values('avg_volume', ascending=False).head(limit)

    print(f'=== Top {limit} Longest Coverage ===')
    display(longest[['symbol', 'category', 'span_years', 'start_date', 'end_date', 'rows']])

    print(f'=== Top {limit} Latest Data ===')
    display(latest[['symbol', 'category', 'end_date', 'last_close']])

    print(f'=== Top {limit} Highest Volume (avg) ===')
    display(vol[['symbol', 'category', 'avg_volume', 'avg_close']])

# %% [markdown]
# ## Configuration
# Adjust the inputs below to point at a different dataset or control the reporting depth.

# %%
DATA_ROOT = Path('../stock_data')
LIMIT = 5
OUTPUT_CSV = None  # e.g. Path('outputs/dataset_overview.csv')

# %% [markdown]
# ## Run Analysis
# Execute the cell below to generate summaries and optional CSV exports.

# %%
files = sorted(DATA_ROOT.glob('*/*.txt'))
if not files:
    raise RuntimeError(f'No symbol text files found in {DATA_ROOT}')

summaries = gather_summaries(files)
df = build_dataframe(summaries)

print_headline_numbers(df)
display_top_lists(df, LIMIT)

if OUTPUT_CSV:
    OUTPUT_CSV.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(OUTPUT_CSV, index=False)
    print(f'[INFO] Detailed summary saved to {OUTPUT_CSV}')
# Out:
# [WARN] Failed to load ../stock_data/Stocks/accp.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/amrh.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/amrhw.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/asns.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/bbrx.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/bolt.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/boxl.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/bxg.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/ehr.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/fmax.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/gnst.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/hayu.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/jt.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/mapi.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/molc.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/otg.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/pbio.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/pxus.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/rbio.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/sail.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/sbt.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/scci.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/scph.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/send.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/sfix.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/srva.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/stnl.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/vist.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/vmet.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/wnfm.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/wspt.us.txt: No columns to parse from file
# [WARN] Failed to load ../stock_data/Stocks/znwaa.us.txt: No columns to parse from file
# === Dataset Overview ===
# Total symbols: 8507
#   - Stocks: 7163
#   - ETFs: 1344
# Overall coverage: 1962-01-02 → 2017-11-10 (20401 days)
# Median observations per symbol: 1819
# === Top 5 Longest Coverage ===
#       symbol category  span_years start_date   end_date   rows
# 4607  ibm.us   Stocks   55.854894 1962-01-02 2017-11-10  14059
# 4041   ge.us   Stocks   55.854894 1962-01-02 2017-11-10  14058
# 4278   gt.us   Stocks   47.854894 1970-01-02 2017-11-10  12073
# 5649  mro.us   Stocks   47.854894 1970-01-02 2017-11-10  12073
# 5414  mcd.us   Stocks   47.854894 1970-01-02 2017-11-10  12075
# === Top 5 Latest Data ===
#          symbol category   end_date  last_close
# 0       aadr.us     ETFs 2017-11-10       56.40
# 5585    mmyt.us   Stocks 2017-11-10       26.90
# 5616    mosy.us   Stocks 2017-11-10        0.73
# 5615  mosc-u.us   Stocks 2017-11-10       10.15
# 5614     mos.us   Stocks 2017-11-10       22.84
# === Top 5 Highest Volume (avg) ===
#        symbol category    avg_volume   avg_close
# 1103   spy.us     ETFs  1.680534e+08  141.275289
# 1356  aapl.us   Stocks  1.066416e+08   22.281018
# 1305   xlf.us     ETFs  9.056787e+07   16.936153
# 936    qqq.us     ETFs  8.054378e+07   58.386467
# 5677  msft.us   Stocks  7.945800e+07   18.984698
